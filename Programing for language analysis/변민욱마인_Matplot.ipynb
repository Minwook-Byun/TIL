# %%
import matplotlib.pyplot as plt 
y = [11,12,13,14,15]
plt.plot(y)
plt.show()

# %%
y = [13,16,15,18,16,20,34]
plt.plot(range(len(y)),y);

# %%
x = ['Mon', 'Tue', 'Wed', 'Thur', 'Fri','Sat', 'Sun']
y = [13,16,15,18,16,20,34]
plt.plot(x,y); #;는 2d 무시기를 안나오게 해준다! 
plt.xlabel('Daily')
plt.ylabel('no. of Books sold')

# %%
x = ['Mon', 'Tue', 'Wed', 'Thur', 'Fri','Sat', 'Sun']
y1 = [13,16,15,18,16,20,34]
y2 = [31,23,45,50,1,8,50]
plt.plot(x,y1, label="sold"); #;는 2d 무시기를 안나오게 해준다! 
plt.plot(x,y2, label="on Sales");
plt.xlabel('Daily')
plt.ylabel('no. of Books sold')
plt.legend(loc='upper left')
plt.title('le petit prince') #한글 쓰면 에러나요~
# Out:
# Text(0.5, 1.0, 'le petit prince')

# %%
x = [13,16,15,18,16,20,34]
y = [31,23,45,50,1,8,50]
plt.plot(x,y, 'bo')

# %%
import numpy as np 
points = np.array([[1,1],[1,2],[1,3],[2,1],[2,2],[2,3],[3,1],[3,2],[3,3]])
p = np.array([2.5,2])

import matplotlib.pyplot as plt 
plt.plot(points[:,0], points[:,1], "ro")
plt.plot(p[0], p[1], "bo")

# %%
x = np.linspace(0,10,20)
y = x**2
plt.plot(x,y)

# %%
x = np.linspace(0,10,20)
y = x**2
plt.plot(x,y, "go-", linewidth =3, markersize=5);

# %%
age = int(input('나이: '))
print(type(age))
old = age + 10
print('십년 후 나이: ', old)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24440/2624888609.py in <module>
# ----> 1 age = int(input('나이: '))
#       2 print(type(age))
#       3 old = age + 10
#       4 print('십년 후 나이: ', old)
#
# ValueError: invalid literal for int() with base 10: ''
